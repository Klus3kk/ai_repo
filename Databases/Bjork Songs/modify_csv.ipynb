# %%
import pandas as pd

# %%
df = pd.read_csv("fiona_apple_songs.csv")
df.head()
# Out:
#                track_name              album_name release_date  \
# 0   I Want You To Love Me  Fetch The Bolt Cutters   2020-04-17
# 1                Shameika  Fetch The Bolt Cutters   2020-04-17
# 2  Fetch The Bolt Cutters  Fetch The Bolt Cutters   2020-04-17
# 3         Under The Table  Fetch The Bolt Cutters   2020-04-17
# 4                   Relay  Fetch The Bolt Cutters   2020-04-17
#
#                  track_id  duration_ms  danceability  energy  key  loudness  \
# 0  73SBAGI4fPFm4VkB3NjXq8       237713         0.528   0.504    9    -8.821
# 1  2pDKE8Q40TDGPl1O11DKKn       248603         0.375   0.776    8    -6.767
# 2  4SdubskbLiOkpsIjRVVsya       298457         0.485   0.488    0   -11.340
# 3  12WhIX6MvI93bS3wPSStSY       201352         0.640   0.494    0    -8.140
# 4  5hnOzmFuGltDDAm008jFDh       289229         0.502   0.574   11    -8.456
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     0       0.0900         0.559          0.041400    0.0936    0.712
# 1     1       0.2740         0.154          0.000082    0.0925    0.647
# 2     1       0.1710         0.526          0.000020    0.0686    0.339
# 3     1       0.0602         0.295          0.000005    0.2480    0.547
# 4     0       0.3850         0.231          0.000000    0.2120    0.474
#
#      tempo
# 0  141.369
# 1  186.814
# 2  150.856
# 3  119.854
# 4   92.101

# %%
df['release_year'] = pd.to_datetime(df['release_date']).dt.year
# df['duration_min'] = df['duration_ms'] / 60000

df = df[['track_name', 'album_name', 'release_date', 'duration_ms', 'key', 'mode',
         'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
         'instrumentalness', 'liveness', 'valence', 'tempo']]
df
# Out:
#                                            track_name  \
# 0                               I Want You To Love Me
# 1                                            Shameika
# 2                              Fetch The Bolt Cutters
# 3                                     Under The Table
# 4                                               Relay
# ..                                                ...
# 58        I Know (feat. Fiona Apple) - RISE Recording
# 59                        Parting Gift - Live Version
# 60                       Fast As You Can - Radio Edit
# 61                        Across the Universe - Remix
# 62  Never Is A Promise - Live from Sessions at Wes...
#
#                                      album_name release_date  duration_ms  \
# 0                        Fetch The Bolt Cutters   2020-04-17       237713
# 1                        Fetch The Bolt Cutters   2020-04-17       248603
# 2                        Fetch The Bolt Cutters   2020-04-17       298457
# 3                        Fetch The Bolt Cutters   2020-04-17       201352
# 4                        Fetch The Bolt Cutters   2020-04-17       289229
# ..                                          ...          ...          ...
# 58  I Know (feat. Fiona Apple) [RISE Recording]   2019-01-25       299613
# 59                  Parting Gift (Live Version)   2005-10-11       216933
# 60                           Fast As You Can EP   1999-11-20       226426
# 61                           Fast As You Can EP   1999-11-20       222506
# 62                           Fast As You Can EP   1999-11-20       382066
#
#     key  mode  danceability  energy  loudness  speechiness  acousticness  \
# 0     9     0         0.528   0.504    -8.821       0.0900        0.5590
# 1     8     1         0.375   0.776    -6.767       0.2740        0.1540
# 2     0     1         0.485   0.488   -11.340       0.1710        0.5260
# 3     0     1         0.640   0.494    -8.140       0.0602        0.2950
# 4    11     0         0.502   0.574    -8.456       0.3850        0.2310
# ..  ...   ...           ...     ...       ...          ...           ...
# 58    0     1         0.520   0.253   -12.407       0.0344        0.3940
# 59    9     0         0.467   0.101   -11.825       0.0759        0.9370
# 60    0     1         0.501   0.697    -9.382       0.0505        0.2500
# 61    4     1         0.578   0.800    -9.469       0.0357        0.0754
# 62    0     1         0.363   0.174   -16.117       0.0445        0.9050
#
#     instrumentalness  liveness  valence    tempo
# 0           0.041400    0.0936    0.712  141.369
# 1           0.000082    0.0925    0.647  186.814
# 2           0.000020    0.0686    0.339  150.856
# 3           0.000005    0.2480    0.547  119.854
# 4           0.000000    0.2120    0.474   92.101
# ..               ...       ...      ...      ...
# 58          0.000131    0.1090    0.219  139.555
# 59          0.000000    0.1030    0.157  169.862
# 60          0.006630    0.0806    0.545  137.929
# 61          0.000337    0.1140    0.507  130.017
# 62          0.000003    0.7850    0.187  136.725
#
# [63 rows x 15 columns]

# %%
df.to_csv('fa_songs.csv', index=False)
