# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Björk_songs_with_lyrics_final.csv')
df.head()
# Out:
#                        track_name                                album_name  \
# 0                           Ocean  Mount Wittenberg Orca (Expanded Edition)
# 1              On and Ever Onward  Mount Wittenberg Orca (Expanded Edition)
# 2  When the World Comes to an End  Mount Wittenberg Orca (Expanded Edition)
# 3                Beautiful Mother  Mount Wittenberg Orca (Expanded Edition)
# 4                     Sharing Orb  Mount Wittenberg Orca (Expanded Edition)
#
#   release_date                track_id  duration_ms  danceability  energy  \
# 0   2023-06-16  7oMy4krSWbBPVHtXBiyHrk       129026         0.104  0.0475
# 1   2023-06-16  2GxGDzq6dpPXUADQsa6o9T       121013         0.719  0.2360
# 2   2023-06-16  09TNNle5fDBPUtLpO6a7BK       188053         0.439  0.3180
# 3   2023-06-16  3shbvAgUyh9nhJa53JN8mB       136360         0.860  0.1540
# 4   2023-06-16  1M4euFTqRYW2xTLhqYGC0C       168000         0.496  0.0524
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0   10   -13.914     1       0.0451         0.590          0.987000    0.1300
# 1    7    -9.063     1       0.0330         0.774          0.000000    0.0621
# 2    5   -11.552     1       0.0460         0.579          0.000007    0.1210
# 3    7   -10.016     1       0.0539         0.679          0.001130    0.1160
# 4    7    -9.198     1       0.0411         0.888          0.000000    0.1900
#
#    valence    tempo                                         lyrics_url  \
# 0    0.038   76.759  https://genius.com/Bjork-living-by-the-ocean-i...
# 1    0.836  112.270                                   Lyrics not found
# 2    0.507  156.127                                   Lyrics not found
# 3    0.398  126.600                                   Lyrics not found
# 4    0.241  118.455                                   Lyrics not found
#
#                                          lyrics_text
# 0  Anchor Song I wrote moving to my house\nWhich ...
# 1                                   Lyrics not found
# 2                                   Lyrics not found
# 3                                   Lyrics not found
# 4                                   Lyrics not found

# %% [markdown]
# # Handle Missing Values

# %%
print("Missing values before cleaning:")
print(df.isnull().sum())
df.dropna(subset=['track_name', 'release_date', 'tempo'], inplace=True)  # Critical columns
df['lyrics_text'].fillna("Lyrics not found", inplace=True)
# Out:
# Missing values before cleaning:
# track_name          0
# album_name          0
# release_date        0
# track_id            0
# duration_ms         0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# lyrics_url          0
# lyrics_text         0
# dtype: int64
# /tmp/ipykernel_6765/1994971616.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['lyrics_text'].fillna("Lyrics not found", inplace=True)

# %% [markdown]
# # Remove Duplicates

# %%
print(f"Duplicates before cleaning: {df.duplicated(subset=['track_name', 'album_name']).sum()}")
df.drop_duplicates(subset=['track_name', 'album_name'], inplace=True)
# Out:
# Duplicates before cleaning: 9

# %% [markdown]
# # Validate Data

# %%
df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce')  # Convert to datetime
df['duration_ms'] = pd.to_numeric(df['duration_ms'], errors='coerce')
df['tempo'] = pd.to_numeric(df['tempo'], errors='coerce')
df.head()
# Out:
#                        track_name                                album_name  \
# 0                           Ocean  Mount Wittenberg Orca (Expanded Edition)
# 1              On and Ever Onward  Mount Wittenberg Orca (Expanded Edition)
# 2  When the World Comes to an End  Mount Wittenberg Orca (Expanded Edition)
# 3                Beautiful Mother  Mount Wittenberg Orca (Expanded Edition)
# 4                     Sharing Orb  Mount Wittenberg Orca (Expanded Edition)
#
#   release_date                track_id  duration_ms  danceability  energy  \
# 0   2023-06-16  7oMy4krSWbBPVHtXBiyHrk       129026         0.104  0.0475
# 1   2023-06-16  2GxGDzq6dpPXUADQsa6o9T       121013         0.719  0.2360
# 2   2023-06-16  09TNNle5fDBPUtLpO6a7BK       188053         0.439  0.3180
# 3   2023-06-16  3shbvAgUyh9nhJa53JN8mB       136360         0.860  0.1540
# 4   2023-06-16  1M4euFTqRYW2xTLhqYGC0C       168000         0.496  0.0524
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0   10   -13.914     1       0.0451         0.590          0.987000    0.1300
# 1    7    -9.063     1       0.0330         0.774          0.000000    0.0621
# 2    5   -11.552     1       0.0460         0.579          0.000007    0.1210
# 3    7   -10.016     1       0.0539         0.679          0.001130    0.1160
# 4    7    -9.198     1       0.0411         0.888          0.000000    0.1900
#
#    valence    tempo                                         lyrics_url  \
# 0    0.038   76.759  https://genius.com/Bjork-living-by-the-ocean-i...
# 1    0.836  112.270                                   Lyrics not found
# 2    0.507  156.127                                   Lyrics not found
# 3    0.398  126.600                                   Lyrics not found
# 4    0.241  118.455                                   Lyrics not found
#
#                                          lyrics_text
# 0  Anchor Song I wrote moving to my house\nWhich ...
# 1                                   Lyrics not found
# 2                                   Lyrics not found
# 3                                   Lyrics not found
# 4                                   Lyrics not found

# %% [markdown]
# # Trim Whitespace

# %%
df['track_name'] = df['track_name'].str.strip()
df['album_name'] = df['album_name'].str.strip()

# %% [markdown]
# # Standardize Case

# %%
df['track_name'] = df['track_name'].str.lower()
df['album_name'] = df['album_name'].str.lower()

# %% [markdown]
# # Remove Unnecessary Columns

# %%
columns_to_drop = ['track_id', 'lyrics_url']  # Add any column you don't want to keep
df.drop(columns=columns_to_drop, inplace=True, errors='ignore')
df.head()
# Out:
#                        track_name                                album_name  \
# 0                           Ocean  Mount Wittenberg Orca (Expanded Edition)
# 1              On and Ever Onward  Mount Wittenberg Orca (Expanded Edition)
# 2  When the World Comes to an End  Mount Wittenberg Orca (Expanded Edition)
# 3                Beautiful Mother  Mount Wittenberg Orca (Expanded Edition)
# 4                     Sharing Orb  Mount Wittenberg Orca (Expanded Edition)
#
#   release_date  duration_ms  danceability  energy  key  loudness  mode  \
# 0   2023-06-16       129026         0.104  0.0475   10   -13.914     1
# 1   2023-06-16       121013         0.719  0.2360    7    -9.063     1
# 2   2023-06-16       188053         0.439  0.3180    5   -11.552     1
# 3   2023-06-16       136360         0.860  0.1540    7   -10.016     1
# 4   2023-06-16       168000         0.496  0.0524    7    -9.198     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0451         0.590          0.987000    0.1300    0.038   76.759
# 1       0.0330         0.774          0.000000    0.0621    0.836  112.270
# 2       0.0460         0.579          0.000007    0.1210    0.507  156.127
# 3       0.0539         0.679          0.001130    0.1160    0.398  126.600
# 4       0.0411         0.888          0.000000    0.1900    0.241  118.455
#
#                                          lyrics_text
# 0  Anchor Song I wrote moving to my house\nWhich ...
# 1                                   Lyrics not found
# 2                                   Lyrics not found
# 3                                   Lyrics not found
# 4                                   Lyrics not found

# %% [markdown]
# # Validate Audio Features

# %%
audio_features = ['danceability', 'energy', 'valence', 'tempo']
for feature in audio_features:
    df[feature] = df[feature].apply(lambda x: np.nan if x < 0 or x > 1 else x)

# %% [markdown]
# # Clean Lyrics Text

# %%
df['lyrics_text'] = df['lyrics_text'].str.replace(r'\n+', '\n', regex=True).str.strip()

# %% [markdown]
# # Save Cleaned Dataset

# %%
df.to_csv('Björk_songs_cleaned.csv', index=False)
print("Data cleaning complete. Saved as 'Björk_songs_cleaned.csv'.")
# Out:
# Data cleaning complete. Saved as 'Björk_songs_cleaned.csv'.
