# %%
import pandas as pd

# %%
df = pd.read_csv("Portishead_songs_with_lyrics2.csv")
df.head()
# Out:
#     track_name album_name release_date                track_id  duration_ms  \
# 0      Silence      Third   2008-01-01  6CLLkUajKRN9LS9PeK3OZF       299586
# 1       Hunter      Third   2008-01-01  0J3bnjae0jkfUpbdHr81Sr       237413
# 2  Nylon Smile      Third   2008-01-01  67oK2xcjCuLe8i3OuUjEUr       196600
# 3      The Rip      Third   2008-01-01  5KX2DSPC6aCA0pdDidTmBC       270946
# 4      Plastic      Third   2008-01-01  6K3gtAIEWNqYHfd4mSEKcT       207573
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.419   0.825   11    -7.453     1       0.0910         0.195
# 1         0.523   0.408   10    -9.563     0       0.0369         0.896
# 2         0.696   0.674    7    -9.953     1       0.1590         0.867
# 3         0.471   0.484    9    -9.414     0       0.0317         0.925
# 4         0.353   0.553    2    -8.145     1       0.0856         0.753
#
#    instrumentalness  liveness  valence    tempo  \
# 0            0.1460    0.3390   0.1040  127.528
# 1            0.1340    0.0980   0.1570  134.179
# 2            0.3710    0.2290   0.3500  127.909
# 3            0.4990    0.0987   0.2360   74.982
# 4            0.0415    0.0861   0.0652  153.656
#
#                                          lyrics_url  \
# 0      https://genius.com/Portishead-silence-lyrics
# 1       https://genius.com/Portishead-hunter-lyrics
# 2  https://genius.com/Portishead-nylon-smile-lyrics
# 3      https://genius.com/Portishead-the-rip-lyrics
# 4      https://genius.com/Portishead-plastic-lyrics
#
#                                          lyrics_text
# 0  [Intro]\nEsteja alerta para as regras dos três...
# 1  [Verse 1]\nNo one said\nWe'd ever known each o...
# 2  [Verse]\nI'd like to laugh at what you said\nB...
# 3  [Verse 1]\nAs she walks in the room\nCentered ...
# 4  [Verse 1]\nI wonder why\nI don't know what you...

# %%
df['track_name']
# Out:
# 0                           Silence
# 1                            Hunter
# 2                       Nylon Smile
# 3                           The Rip
# 4                           Plastic
#                   ...
# 66                             Numb
# 67                 Numbed In Moscow
# 68            Revenge Of The Number
# 69                Numb-Earth Linger
# 70    A Tribute To Monk & Canatella
# Name: track_name, Length: 71, dtype: object

# %%
df.columns
# Out:
# Index(['track_name', 'album_name', 'release_date', 'track_id', 'duration_ms',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'lyrics_url', 'lyrics_text'],
#       dtype='object')

# %%
# Filter out rows with "Lyrics not found" or "Error" in the lyrics_text column
df = df[~df['lyrics_text'].isin(["Lyrics not found", "Error", "null"])]

# %%
# Standardize case and trim whitespace in text columns
df['track_name'] = df['track_name'].str.title().str.strip()
df['album_name'] = df['album_name'].str.title().str.strip()
df['lyrics_text'] = df['lyrics_text'].str.strip()

# %%
# Convert release_date to datetime format
df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce')

# %%
# Convert columns to appropriate numeric data types, coerce errors to NaN
numeric_columns = ['duration_ms', 'danceability', 'energy', 'key', 'loudness', 'mode', 
                   'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']

df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# %%
df.dropna(subset=numeric_columns, inplace=True)

# %%
# Remove duplicates based on the track_id
df.drop_duplicates(subset='track_id', keep='first', inplace=True)

# %%
import re


# Ensure 'lyrics_text' column only processes non-null strings
df['lyrics_text'] = df['lyrics_text'].apply(lambda x: re.sub(r"\[.*?\]", "", str(x)).strip() if isinstance(x, str) else x)

# %%
# Cleaned dataset for data analysis (excluding track_id and lyrics_url)
data_analysis_df = df.drop(columns=['track_id', 'lyrics_url'])


# Dataset for auto-lyrics (only track_name and lyrics_text)
auto_lyrics_df = df[['track_name', 'lyrics_text']]

# %%
# Display the first few rows of each to verify
print("Data Analysis Dataset:")
display(data_analysis_df.head())
# Out:
# Data Analysis Dataset:
#     track_name album_name release_date  duration_ms  danceability  energy  \
# 0      Silence      Third   2008-01-01       299586         0.419   0.825
# 1       Hunter      Third   2008-01-01       237413         0.523   0.408
# 2  Nylon Smile      Third   2008-01-01       196600         0.696   0.674
# 3      The Rip      Third   2008-01-01       270946         0.471   0.484
# 4      Plastic      Third   2008-01-01       207573         0.353   0.553
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0   11    -7.453     1       0.0910         0.195            0.1460    0.3390
# 1   10    -9.563     0       0.0369         0.896            0.1340    0.0980
# 2    7    -9.953     1       0.1590         0.867            0.3710    0.2290
# 3    9    -9.414     0       0.0317         0.925            0.4990    0.0987
# 4    2    -8.145     1       0.0856         0.753            0.0415    0.0861
#
#    valence    tempo                                        lyrics_text
# 0   0.1040  127.528  Esteja alerta para as regras dos três\nO que v...
# 1   0.1570  134.179  No one said\nWe'd ever known each other\nAnd n...
# 2   0.3500  127.909  I'd like to laugh at what you said\nBut I just...
# 3   0.2360   74.982  As she walks in the room\nCentered and tall\nH...
# 4   0.0652  153.656  I wonder why\nI don't know what you see\nOf co...

# %%
print("\nAuto-Lyrics Dataset:")
display(auto_lyrics_df.head())
# Out:
# Auto-Lyrics Dataset:
#     track_name                                        lyrics_text
# 0      Silence  Esteja alerta para as regras dos três\nO que v...
# 1       Hunter  No one said\nWe'd ever known each other\nAnd n...
# 2  Nylon Smile  I'd like to laugh at what you said\nBut I just...
# 3      The Rip  As she walks in the room\nCentered and tall\nH...
# 4      Plastic  I wonder why\nI don't know what you see\nOf co...

# %%
# Save both datasets as CSV files
data_analysis_df.to_csv('portishead_data_analysis.csv', index=False)
auto_lyrics_df.to_csv('portishead_auto_lyrics.csv', index=False)
